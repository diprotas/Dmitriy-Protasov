# %%
import math

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.cos(2*3.14)
# Out:
# 0.9999949269133752

# %%
math.cos(2*math.pi)
# Out:
# 1.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import cowsay

cowsay.cow(str(math.pi))
# Out:
#   _________________
# | 3.141592653589793 |
# ...
#                  \
#                   \
#                     ^__^
#                     (oo)\_______
#                     (__)\       )\/\
#                         ||----w |
#                         ||     ||

# %%
import os

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jul 13 13:33 sample_data

# %%
# !pip install cowsay
# Out:
# ...
#   Using cached cowsay-4.0-py2.py3-none-any.whl (24 kB)
# ...

# %%
# получаем доступ к гугл-диску (способ 2)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive -l
# Out:
# total 1092234
# -rw------- 1 root root   2445097 Jun  7  2022  12.xlsx
# -rw------- 1 root root 501059781 Jun  7  2022 '2022_Google Data Studio_Руководство для начинающих.mp4'
# -rw------- 1 root root     14141 Feb 20 13:32  ABCC1.xlsx
# -rw------- 1 root root     13975 Feb 20 13:15  ABCC.xlsx
# -rw------- 1 root root    101702 Feb 20 14:12 'abc_xyz_ipynb .ipynb'
# drwx------ 2 root root      4096 Sep  1  2022  AI
# -rw------- 1 root root 500375944 Jun  7  2022  Anaconda3-2021.05-Windows-x86_64.exe
# drwx------ 2 root root      4096 Apr  5  2016 'Auto Call Recorder'
# -rw------- 1 root root   1475504 Sep 20  2019 'Car Features and MSRP data.csv'
# -rw------- 1 root root       175 Jun  9  2022 'Car Features and MSRP data.gsheet'
# drwx------ 2 root root      4096 Jul 25  2020 'Colab Notebooks'
# -rw------- 1 root root  31136044 Jul 19  2022  credit_score_classification_train.csv
# -rw------- 1 root root       175 Jun  5  2022  customers.csv.gsheet
# ...

# %%
# !ls /content/drive/MyDrive/SkillBox/Python -l
# Out:
# total 7207
# -rw------- 1 root root   37836 Jul 13 12:51  10.2_SkillBox_Кортежи.ipynb
# -rw------- 1 root root   25070 Jul 13 11:08  10.2_SkillBox_Кортежи_Практика.ipynb
# -rw------- 1 root root  530950 Jul 13 09:08 '10.2 Кортежи.pdf'
# -rw------- 1 root root  894963 Jul 16 18:35  10.3_SkillBox_Множества.ipynb
# -rw------- 1 root root   38795 Jul 13 15:43  10.3_SkillBox_Множества_Практика.ipynb
# -rw------- 1 root root  225872 Jul 13 11:09 '10.3 Множества.pdf'
# -rw------- 1 root root   26663 Jul 13 18:17  10.4_SkillBox_Словари.ipynb
# -rw------- 1 root root   56492 Jul 13 23:21  10.4_SkillBox_Словари_Практика.ipynb
# -rw------- 1 root root   24070 Jul 13 17:50  10.5_SkillBox_List_comprehensions.ipynb
# -rw------- 1 root root  444735 Jul 14 10:41  10.7_SkillBox_Домашнее_задание.ipynb
# -rw------- 1 root root  103636 Jul 17 09:43 '11.1_SkillBox_Чтение_файлов_в_Python, хранящихся  в Google Drive.ipynb'
# ...
