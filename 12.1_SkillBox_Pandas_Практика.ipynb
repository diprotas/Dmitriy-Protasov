# %% [markdown]
# ### Pandas. Практическое задание
#
# В этом практическом задании одна обязательная задача.
#
# *Обязательные задачи* нужно сделать, чтобы проверить, что вы действительно усвоили материал урока. Если у вас всё получилось, вы можете переходить к следующему уроку.
#
# Удачи!

# %% [markdown]
# Цель практического задания — научиться создавать датафреймы.
#
# В конце ноутбука вы можете найти ответы для самостоятельной проверки.

# %% [markdown]
# **Обязательные задачи**

# %% [markdown]
# **Задача 1**
#
# Дана таблица с количеством учеников в параллели первых классов, состоящая из двух колонок:
#
# - **class:** Название класса.
# - **count:** Количество учеников в классе.
#
# <p align="left">
#   <img src="https://drive.google.com/uc?id=1J90nhGw_5GePyz-ilnx0lYXguKOn_-9V" alt="drawing" width="110"/>
# </p>
#
# Ваша задача — создать датафрейм для этой таблицы несколькими способами:

# %%
# Импортируйте pandas
import pandas as pd

# %% [markdown]
# 1. С помощью матрицы (списка списков)

# %%
# Допишите код
data = [['1А', 25],['1Б',31],['1В',28]]
df1 = pd.DataFrame(data, columns = ['class','count'])
df1
# Out:
#   class  count
# 0    1А     25
# 1    1Б     31
# 2    1В     28

# %% [markdown]
# 2. С помощью списка словарей

# %%
# Допишите код
data = {'class' : ['1А','1Б','1В'],
        'count' : [25,31,28]}
df2 = pd.DataFrame(data, columns = ['class','count'])
df2
# Out:
#   class  count
# 0    1А     25
# 1    1Б     31
# 2    1В     28

# %% [markdown]
# 3. С помощью Series

# %%
# Допишите код
series = {'class' : pd.Series(['1А','1Б','1В']),
          'count' : pd.Series([25,31,28])}
df3 = pd.DataFrame(series)
df3
# Out:
#   class  count
# 0    1А     25
# 1    1Б     31
# 2    1В     28

# %% [markdown]
# # В Pandas можно выполнять итерацию по строкам тремя способами, используя range(len(df)), iterrows() и itertuples().

# %%
print("Method 1:")
for index in range(len(df3)): print(df3["class"][index], end = " ")
# Out:
# Method 1:
# 1А 1Б 1В

# %%
print("\nMethod 2:")
for index, row in df3.iterrows(): print(row["class"], end = " ")
# Out:
# Method 2:
# 1А 1Б 1В

# %%
print("\nMethod 3:")
for row in df3.itertuples(): print(row[1], end = " ")
# Out:
# Method 3:
# 1А 1Б 1В

# %%
df = pd.DataFrame({'num_legs': [4, 2], 'num_wings': [0, 2]},  index=['dog', 'hawk'])
df
# Out:
#       num_legs  num_wings
# dog          4          0
# hawk         2          2

# %%
for row in df.itertuples():
    print(row[2])
# Out:
# 0
# 2

# %% [markdown]
# Официальная документация Pandas предупреждает, что итерация - это медленный процесс. Если вы перебираете DataFrame для изменения данных, векторизация будет более быстрой альтернативой. Кроме того, не рекомендуется изменять данные во время итерации по строкам, поскольку Pandas иногда возвращает копию данных в строке, а не ее ссылку, что означает, что не все данные на самом деле будут изменены.

# %%
df['num_legs_quadr'] = df['num_legs'].apply(lambda x: x*x)

# %%
df
# Out:
#       num_legs  num_wings  num_legs_quadr
# dog          4          0              16
# hawk         2          2               4

# %%
import pandas as pd

#create dataframe
df_marks = pd.DataFrame({
    'name': ['apple', 'banana', 'orange', 'mango'],
	'calories': [68, 74, 77, 78]})

df_marks
# Out:
#      name  calories
# 0   apple        68
# 1  banana        74
# 2  orange        77
# 3   mango        78

# %%
#iterate through each row of dataframe
for index, row in df_marks.iterrows():
    print(index, ': ', row['name'], 'has', row['calories'], 'calories.')
# Out:
# 0 :  apple has 68 calories.
# 1 :  banana has 74 calories.
# 2 :  orange has 77 calories.
# 3 :  mango has 78 calories.

# %% [markdown]
# # Перебор столбцов в кадре данных pandas:

# %%
df1 = pd.DataFrame(
                    {
                        "A": ["A0", "A1", "A2", "A3"],
                        "B": ["B0", "B1", "B2", "B3"],
                        "C": ["C0", "C1", "C2", "C3"],
                        "D": ["D0", "D1", "D2", "D3"],
                    },
#                    index=[0, 1, 2, 3],
)
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
for name, values in df1.items ():
   print(values)
# Out:
# 0    A0
# 1    A1
# 2    A2
# 3    A3
# Name: A, dtype: object 0    B0
# 1    B1
# 2    B2
# 3    B3
# Name: B, dtype: object 0    C0
# 1    C1
# 2    C2
# 3    C3
# Name: C, dtype: object 0    D0
# 1    D1
# 2    D2
# 3    D3
# Name: D, dtype: object

# %%
df1 = pd.DataFrame(
                    {
                        "A": ["A0", "A1", "A2", "A3"],
                        "B": ["B0", "B1", "B2", "B3"],
                        "C": ["C0", "C1", "C2", "C3"],
                        "D": ["D0", "D1", "D2", "D3"],
                    },
#                    index=[0, 1, 2, 3],
)


In [2]: df2 = pd.DataFrame(
                    {
                        "A": ["A4", "A5", "A6", "A7"],
                        "B": ["B4", "B5", "B6", "B7"],
                        "C": ["C4", "C5", "C6", "C7"],
                        "D": ["D4", "D5", "D6", "D7"],
                  },
 #                   index=[4, 5, 6, 7],
 )


In [3]: df3 = pd.DataFrame(
                  {
                        "A": ["A8", "A9", "A10", "A11"],
                        "B": ["B8", "B9", "B10", "B11"],
                        "C": ["C8", "C9", "C10", "C11"],
                        "D": ["D8", "D9", "D10", "D11"],
                  },
 #                   index=[8, 9, 10, 11],
  )


frames = [df1, df2, df3]
frames
# Out:
# [    A   B   C   D
#  0  A0  B0  C0  D0
#  1  A1  B1  C1  D1
#  2  A2  B2  C2  D2
#  3  A3  B3  C3  D3,
#      A   B   C   D
#  4  A4  B4  C4  D4
#  5  A5  B5  C5  D5
#  6  A6  B6  C6  D6
#  7  A7  B7  C7  D7,
#        A    B    C    D
#  8    A8   B8   C8   D8
#  9    A9   B9   C9   D9
#  10  A10  B10  C10  D10
#  11  A11  B11  C11  D11]

# %%
result = pd.concat(frames, axis = 0)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat(frames, axis = 1)
result
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |
#
# |

# %% [markdown]
# **Ответы для самостоятельной проверки**

# %%
import pandas as pd

# %%
# 1.

data = [['1A', 25],
        ['1Б', 31],
        ['1B', 28]]
df1 = pd.DataFrame(data, columns = ['class', 'count'])
df1
# Out:
#   class  count
# 0    1A     25
# 1    1Б     31
# 2    1B     28

# %%
# 2.

data = [{'class': '1A', 'count': 25},
        {'class': '1Б', 'count': 31},
        {'class': '1B', 'count': 28}]
df2 = pd.DataFrame(data)
df2
# Out:
#   class  count
# 0    1A     25
# 1    1Б     31
# 2    1B     28

# %%
# 3.

series = {'class': pd.Series(['1A', '1Б', '1B']),
          'count': pd.Series([25, 31, 28])}
df3 = pd.DataFrame(series)
df3
# Out:
#   class  count
# 0    1A     25
# 1    1Б     31
# 2    1B     28
