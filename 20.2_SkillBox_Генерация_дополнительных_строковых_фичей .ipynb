# разделим строковое значение с помощью символа '://'
df.region_url.str.lower().str.split('://')
# Out:
# 0        [https, chattanooga.craigslist.org]
# 1          [https, newjersey.craigslist.org]
# 2               [https, reno.craigslist.org]
# 3       [https, fayetteville.craigslist.org]
# 4          [https, knoxville.craigslist.org]
#                         ...
# 9614      [https, chautauqua.craigslist.org]
# 9615      [https, binghamton.craigslist.org]
# 9616           [https, salem.craigslist.org]
# 9617         [https, madison.craigslist.org]
# 9618         [https, norfolk.craigslist.org]
# Name: region_url, Length: 9619, dtype: object

# %%
# возьмем второй элемент
df.region_url.str.lower().str.split('://').str[1]
# Out:
# 0        chattanooga.craigslist.org
# 1          newjersey.craigslist.org
# 2               reno.craigslist.org
# 3       fayetteville.craigslist.org
# 4          knoxville.craigslist.org
#                    ...
# 9614      chautauqua.craigslist.org
# 9615      binghamton.craigslist.org
# 9616           salem.craigslist.org
# 9617         madison.craigslist.org
# 9618         norfolk.craigslist.org
# Name: region_url, Length: 9619, dtype: object

# %%
# разделим результат с помощью точки
df.region_url.str.lower().str.split('://').str[1].str.split('.')
# Out:
# 0        [chattanooga, craigslist, org]
# 1          [newjersey, craigslist, org]
# 2               [reno, craigslist, org]
# 3       [fayetteville, craigslist, org]
# 4          [knoxville, craigslist, org]
#                      ...
# 9614      [chautauqua, craigslist, org]
# 9615      [binghamton, craigslist, org]
# 9616           [salem, craigslist, org]
# 9617         [madison, craigslist, org]
# 9618         [norfolk, craigslist, org]
# Name: region_url, Length: 9619, dtype: object

# %%
# %%time
df.region_url.str.lower().str.split('://').str[1].str.split('.').str[0]
# CPU times: user 29.2 ms, sys: 2.26 ms, total: 31.4 ms
# Wall time: 30.5 ms
# Out:
# CPU times: user 27.9 ms, sys: 3.91 ms, total: 31.8 ms
# Wall time: 32.9 ms
# 0        chattanooga
# 1          newjersey
# 2               reno
# 3       fayetteville
# 4          knoxville
#             ...
# 9614      chautauqua
# 9615      binghamton
# 9616           salem
# 9617         madison
# 9618         norfolk
# Name: region_url, Length: 9619, dtype: object

# %% [markdown]
# Сделаем теже преобразования с помощью lambda

# %%
# %%time
df.region_url.apply(lambda x: x.lower().split('://')[1].split('.')[0])
# CPU times: user 10.1 ms, sys: 637 µs, total: 10.7 ms
# Wall time: 10.6 ms
# Out:
# CPU times: user 12.1 ms, sys: 0 ns, total: 12.1 ms
# Wall time: 15.4 ms
# 0        chattanooga
# 1          newjersey
# 2               reno
# 3       fayetteville
# 4          knoxville
#             ...
# 9614      chautauqua
# 9615      binghamton
# 9616           salem
# 9617         madison
# 9618         norfolk
# Name: region_url, Length: 9619, dtype: object

# %%
# создадим новую колонку (признак)
df['region_new'] = df.region_url.apply(lambda x: x.lower().split('://')[1].split('.')[0])
df['region_new']
# Out:
# 0        chattanooga
# 1          newjersey
# 2               reno
# 3       fayetteville
# 4          knoxville
#             ...
# 9614      chautauqua
# 9615      binghamton
# 9616           salem
# 9617         madison
# 9618         norfolk
# Name: region_new, Length: 9619, dtype: object

# %%
df[['region','region_new']]
# Out:
#                        region    region_new
# 0                 chattanooga   chattanooga
# 1                north jersey     newjersey
# 2                reno / tahoe          reno
# 3                fayetteville  fayetteville
# 4                   knoxville     knoxville
# ...                       ...           ...
# 9614               chautauqua    chautauqua
# 9615               binghamton    binghamton
# 9616                    salem         salem
# 9617                  madison       madison
# 9618  norfolk / hampton roads       norfolk
#
# [9619 rows x 2 columns]

# %%
df['region_new'].nunique()
# Out:
# 405

# %%
df['region'].nunique()
# Out:
# 393

# %%
df[df['region'] != df['region_new']][['region','region_new']]
# Out:
#                        region    region_new
# 1                north jersey     newjersey
# 2                reno / tahoe          reno
# 5                  des moines     desmoines
# 7                grand rapids   grandrapids
# 8      omaha / council bluffs         omaha
# ...                       ...           ...
# 9609            orange county  orangecounty
# 9611               central NJ           cnj
# 9612     appleton-oshkosh-FDL      appleton
# 9613             fayetteville         fayar
# 9618  norfolk / hampton roads       norfolk
#
# [5193 rows x 2 columns]

# %%
df[df['region'] != df['region_new']].region.unique()
# Out:
# array(['north jersey', 'reno / tahoe', 'des moines', 'grand rapids',
#        'omaha / council bluffs', 'rhode island', 'seattle-tacoma',
#        'hawaii', 'fresno / madera', 'inland empire', 'south jersey',
#        'new haven', 'ft myers / SW florida', 'tyler / east TX',
#        'corpus christi', 'appleton-oshkosh-FDL', 'las vegas',
#        'greenville / upstate', 'anchorage / mat-su', 'port huron',
#        'olympic peninsula', 'san angelo', 'dallas / fort worth',
#        'SF bay area', 'fort collins / north CO', 'st cloud',
#        'colorado springs', 'yuba-sutter', 'san luis obispo',
#        'hudson valley', 'ventura county', 'baton rouge', 'central NJ',
#        'killeen / temple / ft hood', 'jersey shore',
#        'kennewick-pasco-richland', 'western KY', 'kenai peninsula',
#        'detroit metro', 'battle creek', 'st louis, MO',
#        'dayton / springfield', 'kansas city, MO', 'rapid city / west SD',
#        'orange county', 'champaign urbana', 'show low',
#        'sarasota-bradenton', 'tampa bay area', 'raleigh / durham / CH',
#        'new york city', 'gold country', 'fargo / moorhead',
#        'south bend / michiana', 'duluth / superior',
#        "spokane / coeur d'alene", 'twin falls', 'worcester / central MA',
#        'lima / findlay', 'oklahoma city', 'los angeles', 'fayetteville',
#        'columbia / jeff city', 'san antonio', 'monterey bay',
#        'south florida', 'lehigh valley', 'macon / warner robins',
#        'new hampshire', 'treasure coast', 'akron / canton',
#        'lewiston / clarkston', 'eastern NC', 'terre haute', 'eastern CT',
#        'grand island', 'long island', 'fort wayne', 'myrtle beach',
#        'scranton / wilkes-barre', 'daytona beach',
#        'savannah / hinesville', 'western massachusetts',
#        'huntington-ashland', 'el paso', 'winston-salem', 'western slope',
#        'st george', 'minneapolis / st paul', 'palm springs',
#        'santa fe / taos', 'norfolk / hampton roads', 'northwest GA',
#        'washington, DC', 'glens falls', 'new river valley',
#        'oregon coast', 'south coast', 'san diego', 'las cruces',
#        'rochester', 'springfield', 'saginaw-midland-baycity',
#        'wichita falls', 'parkersburg-marietta', 'florida keys',
#        'southwest michigan', 'jackson', 'little rock',
#        'quad cities, IA/IL', 'visalia-tulare', 'plattsburgh-adirondacks',
#        'huntsville / decatur', 'columbus', 'southern maryland',
#        'sioux falls / SE SD', 'finger lakes', 'green bay', 'eau claire',
#        'upper peninsula', 'cedar rapids', 'mcallen / edinburg',
#        'birmingham', 'southwest MN', 'utica-rome-oneida', 'victoria',
#        'skagit / island / SJI', 'medford-ashland', 'salt lake city',
#        'moses lake', 'east idaho', 'cumberland valley',
#        'western maryland', 'great falls', 'southern illinois',
#        'santa barbara', 'kenosha-racine', 'odessa / midland',
#        'zanesville / cambridge', 'athens', 'mohave county', 'tri-cities',
#        'gadsden-anniston', 'sioux city', 'northwest OK',
#        'pullman / moscow', 'new orleans', 'northwest CT', 'hilton head',
#        'manhattan', 'central michigan', 'siskiyou county', 'east oregon',
#        'space coast', 'ann arbor', 'hickory / lenoir', 'north central FL',
#        'twin tiers NY/PA', 'humboldt county', 'mattoon-charleston',
#        'monroe', 'la crosse', 'scottsbluff / panhandle', 'tuscarawas co',
#        'heartland florida', 'outer banks', 'the thumb', 'eastern shore',
#        'muncie / anderson', 'sierra vista', 'jacksonville',
#        'elmira-corning', 'bloomington-normal', 'beaumont / port arthur',
#        'hanford-corcoran', 'northern panhandle', 'southeast missouri',
#        'santa maria', 'fort dodge', 'lafayette / west lafayette',
#        'altoona-johnstown', 'potsdam-canton-massena', 'iowa city',
#        'southwest KS', 'flagstaff / sedona', 'charleston', 'northwest KS',
#        'southeast alaska', 'cape cod / islands', 'college station',
#        'state college', 'corvallis/albany', 'florence', 'bowling green',
#        'eastern kentucky', 'clovis / portales', 'north mississippi',
#        'lake of the ozarks', 'mason city', 'okaloosa / walton',
#        'san marcos', 'southeast IA', 'eastern montana',
#        'central louisiana', 'lake charles', 'northern WI', 'albany',
#        'mendocino county', 'imperial county', 'north platte',
#        'southwest VA', 'northern michigan', 'la salle co', 'southern WV',
#        'ogden-clearfield', 'florence / muscle shoals', 'southwest MS',
#        'south dakota', 'st joseph', 'del rio / eagle pass', 'fort smith',
#        'panama city', 'roswell / carlsbad', 'eastern panhandle',
#        'north dakota', 'waterloo / cedar falls', 'eastern CO',
#        'grand forks', 'pierre / central SD', 'klamath falls', 'richmond',
#        'gulfport / biloxi', 'high rockies', 'northeast SD',
#        'st augustine'], dtype=object)

# %%
df['region_corrected'] = df['region'].apply(lambda x: x.lower().split('/')[0].replace(' ', '').replace('-', ''))
df['region_corrected']
# Out:
# 0        chattanooga
# 1        northjersey
# 2               reno
# 3       fayetteville
# 4          knoxville
#             ...
# 9614      chautauqua
# 9615      binghamton
# 9616           salem
# 9617         madison
# 9618         norfolk
# Name: region_corrected, Length: 9619, dtype: object

# %%
df[df['region_corrected'] != df['region_new']][['region','region_new']]
# Out:
#                      region  region_new
# 1              north jersey   newjersey
# 9              rhode island  providence
# 12           seattle-tacoma     seattle
# 14                   hawaii    honolulu
# 24    ft myers / SW florida   fortmyers
# ...                     ...         ...
# 9597       southeast alaska      juneau
# 9607              rochester         rmn
# 9611             central NJ         cnj
# 9612   appleton-oshkosh-FDL    appleton
# 9613           fayetteville       fayar
#
# [2448 rows x 2 columns]

# %%
df['manufacturer_model'] = df.manufacturer + ': ' + df.model
df['manufacturer_model']
# Out:
# 0           ram: 2500 crew cab big horn
# 1            ford: explorer 4wd 4dr xlt
# 2          volkswagen: golf r hatchback
# 3                          toyota: rav4
# 4           bmw: 1 series 128i coupe 2d
#                      ...
# 9614                       toyota: rav4
# 9615                     jeep: wrangler
# 9616    audi: a3 2.0t premium plus pzev
# 9617                   porsche: cayenne
# 9618        ram: 1500 crew cab big horn
# Name: manufacturer_model, Length: 9619, dtype: object

# %%
df.apply(lambda x: ': '.join([x.manufacturer, x.model]), axis=1)
# Out:
# 0           ram: 2500 crew cab big horn
# 1            ford: explorer 4wd 4dr xlt
# 2          volkswagen: golf r hatchback
# 3                          toyota: rav4
# 4           bmw: 1 series 128i coupe 2d
#                      ...
# 9614                       toyota: rav4
# 9615                     jeep: wrangler
# 9616    audi: a3 2.0t premium plus pzev
# 9617                   porsche: cayenne
# 9618        ram: 1500 crew cab big horn
# Length: 9619, dtype: object

# %%
df.description
# Out:
# 0       Carvana is the safer way to buy a car During t...
# 1       ***Call Us for more information at: 201-635-14...
# 2       Carvana is the safer way to buy a car During t...
# 3       2013 Toyota RAV4 XLE 4dr SUV     Offered by: R...
# 4       Carvana is the safer way to buy a car During t...
#                               ...
# 9614    Transmission:Automatic Exterior Color:WHITE In...
# 9615    2008 Jeep Wrangler X  Offered by: R&L Auto -- ...
# 9616    2011 Audi A3 2.0T Premium Plus PZEV Wagon2011 ...
# 9617    2015 Porsche Cayenne AWD 4dr S E-Hybrid - $31,...
# 9618    Carvana is the safer way to buy a car During t...
# Name: description, Length: 9619, dtype: object

# %%
df['desc_len'] = df.apply(lambda x: len(x.description) , axis=1)
df['desc_len']
# Out:
# 0       4482
# 1        968
# 2       4286
# 3       3241
# 4       4851
#         ...
# 9614    1710
# 9615     948
# 9616     909
# 9617    3644
# 9618    4483
# Name: desc_len, Length: 9619, dtype: int64

# %% [markdown]
# Проверим гипотезу, что количество символов в описании авто влияет на стоимость авто

# %%
colors = {'medium': 'orange', 'high': 'red', 'low': 'green',}

fig, ax = plt.subplots(figsize=(12, 8))
for price_category in colors:
    color = colors[price_category]
    data = df[df['price_category'] == price_category]

    ax.hist(data['desc_len'], color=color, alpha=0.6, bins=20)

plt.ylabel('Количество')
plt.xlabel('Количество символов в описании автомобиля')
plt.title('Количество символов в описании в зависимости от ценовой категории автомобиля')
plt.legend(colors, title="Ценовая категория");

# %%
df['model_in_desc'] = df.apply(lambda x: x.description.count(x.model) , axis=1)
df['model_in_desc']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9614    0
# 9615    0
# 9616    0
# 9617    0
# 9618    0
# Name: model_in_desc, Length: 9619, dtype: int64

# %%
df['model_in_desc'].value_counts()
# Out:
# 0     8502
# 1      790
# 2      101
# 3       49
# 5       31
# 4       23
# 9       14
# 8        9
# 7        9
# 6        9
# 28       9
# 16       8
# 18       6
# 15       5
# 20       5
# 14       5
# 17       4
# 25       3
# 31       3
# 23       3
# 27       3
# 11       3
# 22       3
# 13       3
# 19       3
# 29       2
# 10       2
# 35       2
# 26       1
# 63       1
# 54       1
# 36       1
# 34       1
# 49       1
# 30       1
# 56       1
# 32       1
# 12       1
# Name: model_in_desc, dtype: int64

# %%
# сохраним изменения датафрейма в файл
df.to_csv('/content/drive/MyDrive/SkillBox/Feature_Processing/vehicles_dataset_upd4.csv', index=False)
